# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Line graph
# -I would like to learn how to plot categorical values in a line graph
# For example, to plot the change in the 'pew_religimp' values over different levels of 'educ'. By maybe grouping the data by 'educ' and calculating the mean 'pew_religimp' for each group, then plot this as a line graph.

# %%
deets = pd.read_csv('cces_example_data (1).csv')
deets.head()
# Out:
#    pew_religimp  pew_churatd  sex  educ  nonwhite  age  faminc_new  pid3  \
# 0             2            6    2     2         1   56           6     1
# 1             2            4    2     5         1   53          13     1
# 2             1            2    1     2         1   69          10     2
# 3             2            3    1     6         1   76          97     1
# 4             4            5    2     6         1   83           4     1
#
#    ideo5  QueerPhobia  ...  InterGBiasParty  InterGBiasCand  InterGBiasSup  \
# 0      1     1.000000  ...              -99             -99            -96
# 1      2     3.000000  ...             -100            -100           -100
# 2      5     4.333333  ...               99              99             96
# 3      3     1.000000  ...              -86             -91            -89
# 4      2     1.000000  ...              -80             -88            -87
#
# ...

# %%
fig1, (ax1, ax2) = plt.subplots(1, 2)
ax1.set_title('Age Histogram')
ax2.set_title('Political Identity')

plt.show()

# %%
deets.groupby('Evaluation').count()
# Out:
#             pew_religimp  pew_churatd  sex  educ  nonwhite  age  faminc_new  \
# Evaluation
# 0                    365          365  365   365       365  365         365
# 1                     48           48   48    48        48   48          48
# 2                    202          202  202   202       202  202         202
# 3                     44           44   44    44        44   44          44
#
#             pid3  ideo5  QueerPhobia  ImmiPhobia  InterGBiasParty  \
# Evaluation
# 0            365    365          365         365              365
# 1             48     48           48          48               48
# 2            202    202          202         202              202
# 3             44     44           44          44               44
#
#             InterGBiasCand  InterGBiasSup  LibMediaUse  ConMediaUse  \
# Evaluation
# 0                      365            365          365          365
# 1                       48             48           48           48
# ...

# %%
evaluation_data = deets.groupby('Evaluation')['pew_religimp'].count()
evaluation_data.index

fig2, ax3 = plt.subplots()
ax3.bar(x= evaluation_data.index, height = evaluation_data)
plt.show()

# %%
fig3, ax4 = plt.subplots()
ax4.scatter(x= deets['ConMediaUse'], y = deets['ImmiPhobia'])
ax4.set_xlabel('ConMediaUse')
ax4.set_ylabel('ImmiPhobia')


plt.show()
